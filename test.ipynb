# %%
import pandas as pd
df = pd.read_csv('EntrepriseSalle\Data\entreprises.csv')
df
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# <>:2: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\STORM Tech\AppData\Local\Temp\ipykernel_13792\2137246862.py:2: SyntaxWarning: invalid escape sequence '\D'
#   df = pd.read_csv('EntrepriseSalle\Data\entreprises.csv')
#                              nom   taille  popularite_info  \
# 0                         GEN 42   grande             0.80
# 1                SARL CorpoSense   grande             0.80
# 2               Factory Digitale  moyenne             0.65
# 3                     Yucca Labs   grande             0.80
# 4                     Sirius Net  moyenne             0.55
# 5                 Legal doctrine  moyenne             0.25
# 6                     Easy Relay  moyenne             0.15
# 7   Centre Commercial Mohammedia  moyenne             0.30
# 8                   SARL DATAGIX   grande             0.75
# 9                     EURL DZ-IT  moyenne             0.60
# ...
